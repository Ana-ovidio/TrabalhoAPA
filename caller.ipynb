# %%
from __init__ import main, graph

# %%
tm = main.TriangularMatrix(100)
g = tm.generate_random_graph()
graph.plot_graph(g)

# %%
adj_matrix = tm.binary_adjacency_matrix(g)
elements = tm.matrix_to_array(g)
idx = tm.index_array(elements)
matrix = tm.array_to_matrix(idx)
g = tm.generate_graph_by_matrix(matrix)
